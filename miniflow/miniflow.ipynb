# %% [markdown]
# # Miniflow
# A mini tensorflow done by using graphs and raw python

# %%
def topological_sort(feed_dict):
    """
    Sort generic nodes in topological order using Kahn's Algorithm.

    `feed_dict`: A dictionary where the key is a `Input` node and the value is the respective value feed to that node.

    Returns a list of sorted nodes.
    """

    input_nodes = [n for n in feed_dict.keys()]

    G = {}
    nodes = [n for n in input_nodes]
    while len(nodes) > 0:
        n = nodes.pop(0)
        if n not in G:
            G[n] = {'in': set(), 'out': set()}
        for m in n.outbound_nodes:
            if m not in G:
                G[m] = {'in': set(), 'out': set()}
            G[n]['out'].add(m)
            G[m]['in'].add(n)
            nodes.append(m)

    L = []
    S = set(input_nodes)
    while len(S) > 0:
        n = S.pop()

        if isinstance(n, Input):
            n.value = feed_dict[n]

        L.append(n)
        for m in n.outbound_nodes:
            G[n]['out'].remove(m)
            G[m]['in'].remove(n)
            # if no other incoming edges add to S
            if len(G[m]['in']) == 0:
                S.add(m)
    return L


def forward_pass(output_node, sorted_nodes):
    """
    Performs a forward pass through a list of sorted nodes.

    Arguments:

        `output_node`: A node in the graph, should be the output node (have no outgoing edges).
        `sorted_nodes`: A topologically sorted list of nodes.

    Returns the output Node's value
    """

    for n in sorted_nodes:
        n.forward()

    return output_node.value

# %%
"""
You need to change the Add() class below.
"""

class Node(object):
    def __init__(self, inbound_nodes=[]):
        # Nodes from which this Node receives values
        self.inbound_nodes = inbound_nodes
        # Nodes to which this Node passes values
        self.outbound_nodes = []
        # A calculated value
        self.value = None
        # Add this node as an outbound node on its inputs.
        for n in self.inbound_nodes:
            n.outbound_nodes.append(self)

    # These will be implemented in a subclass.
    def forward(self):
        """
        Forward propagation.

        Compute the output value based on `inbound_nodes` and
        store the result in self.value.
        """
        raise NotImplemented


class Input(Node):
    def __init__(self):
        # an Input node has no inbound nodes,
        # so no need to pass anything to the Node instantiator
        Node.__init__(self)

    # NOTE: Input node is the only node that may
    # receive its value as an argument to forward().
    #
    # All other node implementations should calculate their
    # values from the value of previous nodes, using
    # self.inbound_nodes
    #
    # Example:
    # val0 = self.inbound_nodes[0].value
    def forward(self, value=None):
        if value is not None:
            self.value = value

# %% [markdown]
# ## Add function MiniFlow

# %%
class Add(Node):
    def __init__(self, x, y):
        # You could access `x` and `y` in forward with
        # self.inbound_nodes[0] (`x`) and self.inbound_nodes[1] (`y`)
        Node.__init__(self, [x, y])

    def forward(self):
        """
        Set the value of this node (`self.value`) to the sum of its inbound_nodes.

        Your code here!
        """
        self.value = 0
        for inbound_node in self.inbound_nodes:
            self.value += inbound_node.value

# %%
"""
This script builds and runs a graph with miniflow.

There is no need to change anything to solve this quiz!

However, feel free to play with the network! Can you also
build a network that solves the equation below?

(x + y) + y
"""

x, y = Input(), Input()

f = Add(x, y)

feed_dict = {x: 10, y: 5}

sorted_nodes = topological_sort(feed_dict)
output = forward_pass(f, sorted_nodes)

# NOTE: because topological_sort set the values for the `Input` nodes we could also access
# the value for x with x.value (same goes for y).
print("{} + {} = {} (according to miniflow)".format(feed_dict[x], feed_dict[y], output))
# Out:
# 10 + 5 = 15 (according to miniflow)

# %% [markdown]
# ## Linear function MiniFlow
# ![alt text](neuron.png "neuron")

# %%
import numpy as np

inputs = [6, 14, 3]
weights = [0.5, 0.25, 1.4]
bias = 2

output = np.dot(inputs, weights) + bias
output
# Out:
# 12.699999999999999

# %%
import numpy as np

class Linear(Node):
    def __init__(self, inputs, weights, bias):
        Node.__init__(self, [inputs, weights, bias])

        # NOTE: The weigahts and bias properties here are not
        # numbers, but rather references to other nodes.
        # The weight and bias values are stored within the
        # respective nodesa.

    def forward(self):
        """
        Set self.value to the value of the linear function output.

        Your code goes here!
        """
        inputs = self.inbound_nodes[0].value
        weights = self.inbound_nodes[1].value
        bias = self.inbound_nodes[2].value
        
        # raw solution
        #self.value = bias
        #for x, w in zip(inputs, weights):
        #    self.value += x * w
        
        # numpy solution
        self.value = np.dot(inputs, weights) + bias

# %%
"""
NOTE: Here we're using an Input node for more than a scalar.
In the case of weights and inputs the value of the Input node is
actually a python list!

In general, there's no restriction on the values that can be passed to an Input node.
"""

inputs, weights, bias = Input(), Input(), Input()

f = Linear(inputs, weights, bias)

feed_dict = {
    inputs: [6, 14, 3],
    weights: [0.5, 0.25, 1.4],
    bias: 2
}

graph = topological_sort(feed_dict)
output = forward_pass(f, graph)

print(output) # should be 12.7 with this example
# Out:
# 12.7

# %%
X, W, b = Input(), Input(), Input()

f = Linear(X, W, b)

X_ = np.array([[-1., -2.], [-1, -2]])
W_ = np.array([[2., -3], [2., -3]])
b_ = np.array([-3., -5])

feed_dict = {X: X_, W: W_, b: b_}

graph = topological_sort(feed_dict)
output = forward_pass(f, graph)

"""
Output should be:
[[-9., 4.],
[-9., 4.]]
"""
print(output)
# Out:
# [[-9.  4.]
#  [-9.  4.]]

# %% [markdown]
# ## Sigmoid activation function
# ![alt text](sigmoid_graph.png "sigmoid_graph")
# ![alt text](sigmoid_equation.png "sigmoid_equation")

# %%
class Sigmoid(Node):
    """
    You need to fix the `_sigmoid` and `forward` methods.
    """
    def __init__(self, node):
        Node.__init__(self, [node])

    def _sigmoid(self, x):
        """
        This method is separate from `forward` because it
        will be used later with `backward` as well.

        `x`: A numpy array-like object.

        Return the result of the sigmoid function.

        Your code here!
        """
        return 1 / (1 + np.exp(-x))


    def forward(self):
        """
        Set the value of this node to the result of the
        sigmoid function, `_sigmoid`.

        Your code here!
        """
        input_value = self.inbound_nodes[0].value
        self.value = self._sigmoid(input_value)

# %%
X, W, b = Input(), Input(), Input()

f = Linear(X, W, b)
g = Sigmoid(f)

X_ = np.array([[-1., -2.], [-1, -2]])
W_ = np.array([[2., -3], [2., -3]])
b_ = np.array([-3., -5])

feed_dict = {X: X_, W: W_, b: b_}

graph = topological_sort(feed_dict)
output = forward_pass(g, graph)

"""
Output should be:
[[  1.23394576e-04   9.82013790e-01]
 [  1.23394576e-04   9.82013790e-01]]
"""
print(output)
# Out:
# [[  1.23394576e-04   9.82013790e-01]
#  [  1.23394576e-04   9.82013790e-01]]

# %% [markdown]
# ## Cost MSE
#
# $$C(w,b)=\frac{1}{m}\sum_{x} ||y(x)-a||^2$$
# Here w denotes the collection of all weights in the network, b all the biases, m is the total number of training examples, a is the approximation of y(x) by the network, both a and y(x) are vectors of the same length.

# %%
w1  = np.array([[1, 2], [3, 4]])
np.reshape(w1, -1)
# Out:
# array([1, 2, 3, 4])

# %%
def forward_pass(graph):
    """
    Performs a forward pass through a list of sorted Nodes.

    Arguments:

        `graph`: The result of calling `topological_sort`.
    """
    # Forward pass
    for n in graph:
        n.forward()

class MSE(Node):
    def __init__(self, y, a):
        """
        The mean squared error cost function.
        Should be used as the last node for a network.
        """
        # Call the base class' constructor.
        Node.__init__(self, [y, a])

    def forward(self):
        """
        Calculates the mean squared error.
        """
        # NOTE: We reshape these to avoid possible matrix/vector broadcast
        # errors.
        #
        # For example, if we subtract an array of shape (3,) from an array of shape
        # (3,1) we get an array of shape(3,3) as the result when we want
        # an array of shape (3,1) instead.
        #
        # Making both arrays (3,1) insures the result is (3,1) and does
        # an elementwise subtraction as expected.
        y = self.inbound_nodes[0].value.reshape(-1, 1)
        a = self.inbound_nodes[1].value.reshape(-1, 1)
        m = self.inbound_nodes[0].value.shape[0]

        # self.value = np.sum(np.square(y-a)) / m
        # by np.mean() -> mitja aritmètica
        self.value = np.mean((y - a)**2)

# %%
y, a = Input(), Input()
cost = MSE(y, a)

y_ = np.array([1, 2, 3])
a_ = np.array([4.5, 5, 10])

feed_dict = {y: y_, a: a_}
graph = topological_sort(feed_dict)
# forward pass
forward_pass(graph)

"""
Expected output

23.4166666667
"""
print(cost.value)
# Out:
# [[ 12.25]
#  [  9.  ]
#  [ 49.  ]]
# 23.4166666667

# %% [markdown]
# ## Gradient Descent
#
# ```x = x - learning_rate * gradient_of_x```
#
# x is a parameter used by the neural network (i.e. a single weight or bias).

# %%
def gradient_descent_update(x, gradx, learning_rate):
    """
    Performs a gradient descent update.
    """
    # TODO: Implement gradient descent.
    x = x - learning_rate * gradx
    
    # Return the new value for x
    return x

# %%
"""
Given the starting point of any `x` gradient descent
should be able to find the minimum value of x for the
cost function `f` defined below.
"""
import random

def f(x):
    """
    Quadratic function.

    It's easy to see the minimum value of the function
    is 5 when is x=0.
    """
    return x**2 + 5


def df(x):
    """
    Derivative of `f` with respect to `x`.
    """
    return 2*x


# Random number between 0 and 10,000. Feel free to set x whatever you like.
x = random.randint(0, 10000)
# TODO: Set the learning rate
learning_rate = 0.1
epochs = 100

for i in range(epochs+1):
    cost = f(x)
    gradx = df(x)
    print("EPOCH {}: Cost = {:.3f}, x = {:.3f}".format(i, cost, gradx))
    x = gradient_descent_update(x, gradx, learning_rate)
# Out:
# EPOCH 0: Cost = 12376329.000, x = 7036.000
# EPOCH 1: Cost = 7920852.360, x = 5628.800
# EPOCH 2: Cost = 5069347.310, x = 4503.040
# EPOCH 3: Cost = 3244384.079, x = 3602.432
# EPOCH 4: Cost = 2076407.610, x = 2881.946
# EPOCH 5: Cost = 1328902.671, x = 2305.556
# EPOCH 6: Cost = 850499.509, x = 1844.445
# EPOCH 7: Cost = 544321.486, x = 1475.556
# EPOCH 8: Cost = 348367.551, x = 1180.445
# EPOCH 9: Cost = 222957.033, x = 944.356
# EPOCH 10: Cost = 142694.301, x = 755.485
# EPOCH 11: Cost = 91326.153, x = 604.388
# EPOCH 12: Cost = 58450.538, x = 483.510
# EPOCH 13: Cost = 37410.144, x = 386.808
# EPOCH 14: Cost = 23944.292, x = 309.447
# EPOCH 15: Cost = 15326.147, x = 247.557
# EPOCH 16: Cost = 9810.534, x = 198.046
# EPOCH 17: Cost = 6280.542, x = 158.437
# EPOCH 18: Cost = 4021.347, x = 126.749
# EPOCH 19: Cost = 2575.462, x = 101.399
# EPOCH 20: Cost = 1650.096, x = 81.120
# EPOCH 21: Cost = 1057.861, x = 64.896
# EPOCH 22: Cost = 678.831, x = 51.917
# EPOCH 23: Cost = 436.252, x = 41.533
# EPOCH 24: Cost = 281.001, x = 33.227
# EPOCH 25: Cost = 181.641, x = 26.581
# EPOCH 26: Cost = 118.050, x = 21.265
# EPOCH 27: Cost = 77.352, x = 17.012
# EPOCH 28: Cost = 51.305, x = 13.610
# EPOCH 29: Cost = 34.635, x = 10.888
# EPOCH 30: Cost = 23.967, x = 8.710
# EPOCH 31: Cost = 17.139, x = 6.968
# EPOCH 32: Cost = 12.769, x = 5.574
# EPOCH 33: Cost = 9.972, x = 4.460
# EPOCH 34: Cost = 8.182, x = 3.568
# EPOCH 35: Cost = 7.037, x = 2.854
# EPOCH 36: Cost = 6.303, x = 2.283
# EPOCH 37: Cost = 5.834, x = 1.827
# EPOCH 38: Cost = 5.534, x = 1.461
# EPOCH 39: Cost = 5.342, x = 1.169
# EPOCH 40: Cost = 5.219, x = 0.935
# EPOCH 41: Cost = 5.140, x = 0.748
# EPOCH 42: Cost = 5.090, x = 0.599
# EPOCH 43: Cost = 5.057, x = 0.479
# EPOCH 44: Cost = 5.037, x = 0.383
# EPOCH 45: Cost = 5.023, x = 0.306
# EPOCH 46: Cost = 5.015, x = 0.245
# EPOCH 47: Cost = 5.010, x = 0.196
# EPOCH 48: Cost = 5.006, x = 0.157
# EPOCH 49: Cost = 5.004, x = 0.126
# EPOCH 50: Cost = 5.003, x = 0.100
# EPOCH 51: Cost = 5.002, x = 0.080
# EPOCH 52: Cost = 5.001, x = 0.064
# EPOCH 53: Cost = 5.001, x = 0.051
# EPOCH 54: Cost = 5.000, x = 0.041
# EPOCH 55: Cost = 5.000, x = 0.033
# EPOCH 56: Cost = 5.000, x = 0.026
# EPOCH 57: Cost = 5.000, x = 0.021
# EPOCH 58: Cost = 5.000, x = 0.017
# EPOCH 59: Cost = 5.000, x = 0.013
# EPOCH 60: Cost = 5.000, x = 0.011
# EPOCH 61: Cost = 5.000, x = 0.009
# EPOCH 62: Cost = 5.000, x = 0.007
# EPOCH 63: Cost = 5.000, x = 0.006
# EPOCH 64: Cost = 5.000, x = 0.004
# EPOCH 65: Cost = 5.000, x = 0.004
# EPOCH 66: Cost = 5.000, x = 0.003
# EPOCH 67: Cost = 5.000, x = 0.002
# EPOCH 68: Cost = 5.000, x = 0.002
# EPOCH 69: Cost = 5.000, x = 0.001
# EPOCH 70: Cost = 5.000, x = 0.001
# EPOCH 71: Cost = 5.000, x = 0.001
# EPOCH 72: Cost = 5.000, x = 0.001
# EPOCH 73: Cost = 5.000, x = 0.001
# EPOCH 74: Cost = 5.000, x = 0.000
# EPOCH 75: Cost = 5.000, x = 0.000
# EPOCH 76: Cost = 5.000, x = 0.000
# EPOCH 77: Cost = 5.000, x = 0.000
# EPOCH 78: Cost = 5.000, x = 0.000
# EPOCH 79: Cost = 5.000, x = 0.000
# EPOCH 80: Cost = 5.000, x = 0.000
# EPOCH 81: Cost = 5.000, x = 0.000
# EPOCH 82: Cost = 5.000, x = 0.000
# EPOCH 83: Cost = 5.000, x = 0.000
# EPOCH 84: Cost = 5.000, x = 0.000
# EPOCH 85: Cost = 5.000, x = 0.000
# EPOCH 86: Cost = 5.000, x = 0.000
# EPOCH 87: Cost = 5.000, x = 0.000
# EPOCH 88: Cost = 5.000, x = 0.000
# EPOCH 89: Cost = 5.000, x = 0.000
# EPOCH 90: Cost = 5.000, x = 0.000
# EPOCH 91: Cost = 5.000, x = 0.000
# EPOCH 92: Cost = 5.000, x = 0.000
# EPOCH 93: Cost = 5.000, x = 0.000
# EPOCH 94: Cost = 5.000, x = 0.000
# EPOCH 95: Cost = 5.000, x = 0.000
# EPOCH 96: Cost = 5.000, x = 0.000
# EPOCH 97: Cost = 5.000, x = 0.000
# EPOCH 98: Cost = 5.000, x = 0.000
# EPOCH 99: Cost = 5.000, x = 0.000
# EPOCH 100: Cost = 5.000, x = 0.000

# %% [markdown]
# ## Backpropagation
#
# ![alt text](backprop.png)
# ![alt text](dcdw1-chain.png)
# To find the gradient, you just multiply the gradients for all nodes in front of it going backwards from the cost. This is the idea behind backpropagation. The gradients are passed backwards through the network and used with gradient descent to update the weights and biases. If a node has multiple outgoing nodes, you just sum up the gradients from each node.

# %%
"""
Implement the backward method of the Sigmoid node.
"""
import numpy as np


class Node(object):
    """
    Base class for nodes in the network.

    Arguments:

        `inbound_nodes`: A list of nodes with edges into this node.
    """
    def __init__(self, inbound_nodes=[]):
        """
        Node's constructor (runs when the object is instantiated). Sets
        properties that all nodes need.
        """
        # A list of nodes with edges into this node.
        self.inbound_nodes = inbound_nodes
        # The eventual value of this node. Set by running
        # the forward() method.
        self.value = None
        # A list of nodes that this node outputs to.
        self.outbound_nodes = []
        # New property! Keys are the inputs to this node and
        # their values are the partials of this node with
        # respect to that input.
        self.gradients = {}
        # Sets this node as an outbound node for all of
        # this node's inputs.
        for node in inbound_nodes:
            node.outbound_nodes.append(self)

    def forward(self):
        """
        Every node that uses this class as a base class will
        need to define its own `forward` method.
        """
        raise NotImplementedError

    def backward(self):
        """
        Every node that uses this class as a base class will
        need to define its own `backward` method.
        """
        raise NotImplementedError


class Input(Node):
    """
    A generic input into the network.
    """
    def __init__(self):
        # The base class constructor has to run to set all
        # the properties here.
        #
        # The most important property on an Input is value.
        # self.value is set during `topological_sort` later.
        Node.__init__(self)

    def forward(self):
        # Do nothing because nothing is calculated.
        pass

    def backward(self):
        # An Input node has no inputs so the gradient (derivative)
        # is zero.
        # The key, `self`, is reference to this object.
        self.gradients = {self: 0}
        # Weights and bias may be inputs, so you need to sum
        # the gradient from output gradients.
        for n in self.outbound_nodes:
            grad_cost = n.gradients[self]
            self.gradients[self] += grad_cost * 1


class Linear(Node):
    """
    Represents a node that performs a linear transform.
    """
    def __init__(self, X, W, b):
        # The base class (Node) constructor. Weights and bias
        # are treated like inbound nodes.
        Node.__init__(self, [X, W, b])

    def forward(self):
        """
        Performs the math behind a linear transform.
        """
        X = self.inbound_nodes[0].value
        W = self.inbound_nodes[1].value
        b = self.inbound_nodes[2].value
        self.value = np.dot(X, W) + b

    def backward(self):
        """
        Calculates the gradient based on the output values.
        """
        # Initialize a partial for each of the inbound_nodes.
        self.gradients = {n: np.zeros_like(n.value) for n in self.inbound_nodes}
        # Cycle through the outputs. The gradient will change depending
        # on each output, so the gradients are summed over all outputs.
        for n in self.outbound_nodes:
            # Get the partial of the cost with respect to this node.
            grad_cost = n.gradients[self]
            # Set the partial of the loss with respect to this node's inputs.
            self.gradients[self.inbound_nodes[0]] += np.dot(grad_cost, self.inbound_nodes[1].value.T)
            # Set the partial of the loss with respect to this node's weights.
            self.gradients[self.inbound_nodes[1]] += np.dot(self.inbound_nodes[0].value.T, grad_cost)
            # Set the partial of the loss with respect to this node's bias.
            self.gradients[self.inbound_nodes[2]] += np.sum(grad_cost, axis=0, keepdims=False)


class Sigmoid(Node):
    """
    Represents a node that performs the sigmoid activation function.
    """
    def __init__(self, node):
        # The base class constructor.
        Node.__init__(self, [node])

    def _sigmoid(self, x):
        """
        This method is separate from `forward` because it
        will be used with `backward` as well.

        `x`: A numpy array-like object.
        """
        return 1. / (1. + np.exp(-x))

    def forward(self):
        """
        Perform the sigmoid function and set the value.
        """
        input_value = self.inbound_nodes[0].value
        self.value = self._sigmoid(input_value)

    def backward(self):
        """
        Calculates the gradient using the derivative of
        the sigmoid function.
        """
        # Initialize the gradients to 0.
        self.gradients = {n: np.zeros_like(n.value) for n in self.inbound_nodes}

        # Cycle through the outputs. The gradient will change depending
        # on each output, so the gradients are summed over all outputs.
        for n in self.outbound_nodes:
            # Get the partial of the cost with respect to this node.
            grad_cost = n.gradients[self]
            """
            TODO: Your code goes here!

            Set the gradients property to the gradients with respect to each input.

            NOTE: See the Linear node and MSE node for examples.
            chain rule= it is the product from the backpropagation grad_cost (grad_cost = n.gradients[self])
            with the partial derivative!!!
            """
            sigmoid = self.value
            self.gradients[self.inbound_nodes[0]] += grad_cost * (sigmoid * (1 - sigmoid))


class MSE(Node):
    def __init__(self, y, a):
        """
        The mean squared error cost function.
        Should be used as the last node for a network.
        """
        # Call the base class' constructor.
        Node.__init__(self, [y, a])

    def forward(self):
        """
        Calculates the mean squared error.
        """
        # NOTE: We reshape these to avoid possible matrix/vector broadcast
        # errors.
        #
        # For example, if we subtract an array of shape (3,) from an array of shape
        # (3,1) we get an array of shape(3,3) as the result when we want
        # an array of shape (3,1) instead.
        #
        # Making both arrays (3,1) insures the result is (3,1) and does
        # an elementwise subtraction as expected.
        y = self.inbound_nodes[0].value.reshape(-1, 1)
        a = self.inbound_nodes[1].value.reshape(-1, 1)

        self.m = self.inbound_nodes[0].value.shape[0]
        # Save the computed output for backward.
        self.diff = y - a
        self.value = np.mean(self.diff**2)

    def backward(self):
        """
        Calculates the gradient of the cost.

        This is the final node of the network so outbound nodes
        are not a concern.
        """
        self.gradients[self.inbound_nodes[0]] = (2 / self.m) * self.diff
        self.gradients[self.inbound_nodes[1]] = (-2 / self.m) * self.diff


def topological_sort(feed_dict):
    """
    Sort the nodes in topological order using Kahn's Algorithm.

    `feed_dict`: A dictionary where the key is a `Input` Node and the value is the respective value feed to that Node.

    Returns a list of sorted nodes.
    """

    input_nodes = [n for n in feed_dict.keys()]

    G = {}
    nodes = [n for n in input_nodes]
    while len(nodes) > 0:
        n = nodes.pop(0)
        if n not in G:
            G[n] = {'in': set(), 'out': set()}
        for m in n.outbound_nodes:
            if m not in G:
                G[m] = {'in': set(), 'out': set()}
            G[n]['out'].add(m)
            G[m]['in'].add(n)
            nodes.append(m)

    L = []
    S = set(input_nodes)
    while len(S) > 0:
        n = S.pop()

        if isinstance(n, Input):
            n.value = feed_dict[n]

        L.append(n)
        for m in n.outbound_nodes:
            G[n]['out'].remove(m)
            G[m]['in'].remove(n)
            # if no other incoming edges add to S
            if len(G[m]['in']) == 0:
                S.add(m)
    return L


def forward_and_backward(graph):
    """
    Performs a forward pass and a backward pass through a list of sorted Nodes.

    Arguments:

        `graph`: The result of calling `topological_sort`.
    """
    # Forward pass
    for n in graph:
        n.forward()

    # Backward pass
    # see: https://docs.python.org/2.3/whatsnew/section-slices.html
    for n in graph[::-1]:
        n.backward()

# %%
"""
Test your network here!

No need to change this code, but feel free to tweak it
to test your network!

Make your changes to backward method of the Sigmoid class
"""

X, W, b = Input(), Input(), Input()
y = Input()
f = Linear(X, W, b)
a = Sigmoid(f)
cost = MSE(y, a)

X_ = np.array([[-1., -2.], [-1, -2]])
W_ = np.array([[2.], [3.]])
b_ = np.array([-3.])
y_ = np.array([1, 2])

feed_dict = {
    X: X_,
    y: y_,
    W: W_,
    b: b_,
}

graph = topological_sort(feed_dict)
forward_and_backward(graph)
# return the gradients for each Input
gradients = [t.gradients[t] for t in [X, y, W, b]]

"""
Expected output

[array([[ -3.34017280e-05,  -5.01025919e-05],
       [ -6.68040138e-05,  -1.00206021e-04]]), array([[ 0.9999833],
       [ 1.9999833]]), array([[  5.01028709e-05],
       [  1.00205742e-04]]), array([ -5.01028709e-05])]
"""
print(gradients)
# Out:
# [array([[ -3.34017280e-05,  -5.01025919e-05],
#        [ -6.68040138e-05,  -1.00206021e-04]]), array([[ 0.9999833],
#        [ 1.9999833]]), array([[  5.01028709e-05],
#        [  1.00205742e-04]]), array([ -5.01028709e-05])]

# %% [markdown]
# ## Stochastic Gradient Descent
# Stochastic Gradient Descent (SGD) is a version of Gradient Descent where on each forward pass a batch of data is randomly sampled from total dataset. Remember when we talked about the batch size earlier? That's the size of the batch. Ideally, the entire dataset would be fed into the neural network on each forward pass, but in practice, it's not practical due to memory constraints. SGD is an approximation of Gradient Descent, the more batches processed by the neural network, the better the approximation.
#
# A naïve implementation of SGD involves:
#
# 1. Randomly sample a batch of data from the total dataset.
# 2. Running the network forward and backward to calculate the gradient (with data from (1)).
# 3. Apply the gradient descent update. ![alt text](sgd_update.png)
# 4. Repeat steps 1-3 until convergence or the loop is stopped by another mechanism (i.e. the number of epochs).

# %%
def sgd_update(trainables, learning_rate=1e-2):
    """
    Updates the value of each trainable with SGD.

    Arguments:

        `trainables`: A list of `Input` Nodes representing weights/biases.
        `learning_rate`: The learning rate.
    """
    # TODO: update all the `trainables` with SGD
    # You can access and assign the value of a trainable with `value` attribute.
    # Example:
    # for t in trainables:
    #   t.value = your implementation here
    for t in trainables:
        t.value = t.value - learning_rate * t.gradients[t]

# %%
"""
Check out the new network architecture and dataset!

Notice that the weights and biases are
generated randomly.

No need to change anything, but feel free to tweak
to test your network, play around with the epochs, batch size, etc!
"""

import numpy as np
from sklearn.datasets import load_boston
from sklearn.utils import shuffle, resample

# Load data
data = load_boston()
X_ = data['data']
y_ = data['target']

# Normalize data
X_ = (X_ - np.mean(X_, axis=0)) / np.std(X_, axis=0)

n_features = X_.shape[1]
n_hidden = 10
W1_ = np.random.randn(n_features, n_hidden)
b1_ = np.zeros(n_hidden)
W2_ = np.random.randn(n_hidden, 1)
b2_ = np.zeros(1)

# Neural network
X, y = Input(), Input()
W1, b1 = Input(), Input()
W2, b2 = Input(), Input()

l1 = Linear(X, W1, b1)
s1 = Sigmoid(l1)
l2 = Linear(s1, W2, b2)
cost = MSE(y, l2)

feed_dict = {
    X: X_,
    y: y_,
    W1: W1_,
    b1: b1_,
    W2: W2_,
    b2: b2_
}

epochs = 1000
# Total number of examples
m = X_.shape[0]
batch_size = 11
steps_per_epoch = m // batch_size

graph = topological_sort(feed_dict)
trainables = [W1, b1, W2, b2]

print("Total number of examples = {}".format(m))

# Step 4
for i in range(epochs):
    loss = 0
    for j in range(steps_per_epoch):
        # Step 1
        # Randomly sample a batch of examples
        X_batch, y_batch = resample(X_, y_, n_samples=batch_size)

        # Reset value of X and y Inputs
        X.value = X_batch
        y.value = y_batch

        # Step 2
        forward_and_backward(graph)

        # Step 3
        sgd_update(trainables)

        loss += graph[-1].value

    print("Epoch: {}, Loss: {:.3f}".format(i+1, loss/steps_per_epoch))
# Out:
# Total number of examples = 506
# Epoch: 1, Loss: 137.786
# Epoch: 2, Loss: 33.297
# Epoch: 3, Loss: 26.488
# Epoch: 4, Loss: 20.102
# Epoch: 5, Loss: 27.499
# Epoch: 6, Loss: 22.509
# Epoch: 7, Loss: 17.468
# Epoch: 8, Loss: 23.890
# Epoch: 9, Loss: 17.394
# Epoch: 10, Loss: 14.918
# Epoch: 11, Loss: 15.996
# Epoch: 12, Loss: 12.336
# Epoch: 13, Loss: 15.849
# Epoch: 14, Loss: 13.314
# Epoch: 15, Loss: 10.286
# Epoch: 16, Loss: 11.584
# Epoch: 17, Loss: 12.928
# Epoch: 18, Loss: 14.513
# Epoch: 19, Loss: 9.916
# Epoch: 20, Loss: 12.342
# Epoch: 21, Loss: 11.001
# Epoch: 22, Loss: 11.408
# Epoch: 23, Loss: 10.584
# Epoch: 24, Loss: 11.644
# Epoch: 25, Loss: 7.105
# Epoch: 26, Loss: 9.895
# Epoch: 27, Loss: 10.794
# Epoch: 28, Loss: 9.743
# Epoch: 29, Loss: 8.583
# Epoch: 30, Loss: 8.638
# Epoch: 31, Loss: 9.257
# Epoch: 32, Loss: 9.668
# Epoch: 33, Loss: 9.507
# Epoch: 34, Loss: 7.237
# Epoch: 35, Loss: 9.732
# Epoch: 36, Loss: 8.582
# Epoch: 37, Loss: 8.429
# Epoch: 38, Loss: 8.887
# Epoch: 39, Loss: 8.433
# Epoch: 40, Loss: 8.756
# Epoch: 41, Loss: 8.978
# Epoch: 42, Loss: 8.389
# Epoch: 43, Loss: 8.311
# Epoch: 44, Loss: 8.837
# Epoch: 45, Loss: 6.888
# Epoch: 46, Loss: 9.077
# Epoch: 47, Loss: 7.976
# Epoch: 48, Loss: 7.459
# Epoch: 49, Loss: 6.868
# Epoch: 50, Loss: 6.988
# Epoch: 51, Loss: 7.151
# Epoch: 52, Loss: 7.568
# Epoch: 53, Loss: 6.217
# Epoch: 54, Loss: 7.438
# Epoch: 55, Loss: 5.595
# Epoch: 56, Loss: 7.211
# Epoch: 57, Loss: 6.600
# Epoch: 58, Loss: 7.447
# Epoch: 59, Loss: 5.795
# Epoch: 60, Loss: 7.204
# Epoch: 61, Loss: 6.413
# Epoch: 62, Loss: 7.054
# Epoch: 63, Loss: 7.659
# Epoch: 64, Loss: 6.350
# Epoch: 65, Loss: 6.499
# Epoch: 66, Loss: 7.711
# Epoch: 67, Loss: 7.396
# Epoch: 68, Loss: 5.723
# Epoch: 69, Loss: 6.035
# Epoch: 70, Loss: 6.757
# Epoch: 71, Loss: 8.633
# Epoch: 72, Loss: 7.146
# Epoch: 73, Loss: 6.768
# Epoch: 74, Loss: 6.098
# Epoch: 75, Loss: 6.619
# Epoch: 76, Loss: 5.284
# Epoch: 77, Loss: 6.940
# Epoch: 78, Loss: 6.820
# Epoch: 79, Loss: 6.345
# Epoch: 80, Loss: 6.766
# Epoch: 81, Loss: 6.829
# Epoch: 82, Loss: 7.031
# Epoch: 83, Loss: 6.354
# Epoch: 84, Loss: 6.112
# Epoch: 85, Loss: 6.187
# Epoch: 86, Loss: 5.510
# Epoch: 87, Loss: 5.630
# Epoch: 88, Loss: 6.154
# Epoch: 89, Loss: 6.261
# Epoch: 90, Loss: 6.260
# Epoch: 91, Loss: 5.616
# Epoch: 92, Loss: 5.963
# Epoch: 93, Loss: 5.243
# Epoch: 94, Loss: 6.718
# Epoch: 95, Loss: 6.965
# Epoch: 96, Loss: 6.703
# Epoch: 97, Loss: 5.929
# Epoch: 98, Loss: 5.775
# Epoch: 99, Loss: 6.141
# Epoch: 100, Loss: 5.793
# Epoch: 101, Loss: 6.988
# Epoch: 102, Loss: 6.799
# Epoch: 103, Loss: 6.615
# Epoch: 104, Loss: 5.582
# Epoch: 105, Loss: 6.028
# Epoch: 106, Loss: 5.732
# Epoch: 107, Loss: 5.914
# Epoch: 108, Loss: 5.995
# Epoch: 109, Loss: 6.647
# Epoch: 110, Loss: 5.982
# Epoch: 111, Loss: 5.449
# Epoch: 112, Loss: 5.650
# Epoch: 113, Loss: 4.386
# Epoch: 114, Loss: 5.056
# Epoch: 115, Loss: 6.521
# Epoch: 116, Loss: 5.739
# Epoch: 117, Loss: 5.358
# Epoch: 118, Loss: 5.430
# Epoch: 119, Loss: 5.404
# Epoch: 120, Loss: 4.973
# Epoch: 121, Loss: 6.341
# Epoch: 122, Loss: 5.532
# Epoch: 123, Loss: 5.330
# Epoch: 124, Loss: 5.319
# Epoch: 125, Loss: 5.606
# Epoch: 126, Loss: 4.513
# Epoch: 127, Loss: 5.133
# Epoch: 128, Loss: 6.193
# Epoch: 129, Loss: 4.738
# Epoch: 130, Loss: 5.390
# Epoch: 131, Loss: 5.054
# Epoch: 132, Loss: 5.626
# Epoch: 133, Loss: 5.226
# Epoch: 134, Loss: 6.723
# Epoch: 135, Loss: 5.408
# Epoch: 136, Loss: 4.999
# Epoch: 137, Loss: 4.645
# Epoch: 138, Loss: 4.792
# Epoch: 139, Loss: 4.453
# Epoch: 140, Loss: 6.238
# Epoch: 141, Loss: 4.597
# Epoch: 142, Loss: 4.612
# Epoch: 143, Loss: 5.877
# Epoch: 144, Loss: 5.709
# Epoch: 145, Loss: 5.354
# Epoch: 146, Loss: 3.717
# Epoch: 147, Loss: 5.501
# Epoch: 148, Loss: 5.592
# Epoch: 149, Loss: 5.332
# Epoch: 150, Loss: 4.000
# Epoch: 151, Loss: 4.876
# Epoch: 152, Loss: 4.292
# Epoch: 153, Loss: 4.685
# Epoch: 154, Loss: 4.750
# Epoch: 155, Loss: 4.602
# Epoch: 156, Loss: 5.211
# Epoch: 157, Loss: 4.892
# Epoch: 158, Loss: 4.923
# Epoch: 159, Loss: 5.480
# Epoch: 160, Loss: 6.108
# Epoch: 161, Loss: 4.524
# Epoch: 162, Loss: 5.244
# Epoch: 163, Loss: 5.021
# Epoch: 164, Loss: 5.045
# Epoch: 165, Loss: 5.008
# Epoch: 166, Loss: 4.964
# Epoch: 167, Loss: 4.450
# Epoch: 168, Loss: 4.550
# Epoch: 169, Loss: 4.404
# Epoch: 170, Loss: 4.466
# Epoch: 171, Loss: 5.330
# Epoch: 172, Loss: 5.008
# Epoch: 173, Loss: 5.176
# Epoch: 174, Loss: 4.910
# Epoch: 175, Loss: 3.921
# Epoch: 176, Loss: 5.140
# Epoch: 177, Loss: 4.848
# Epoch: 178, Loss: 4.478
# Epoch: 179, Loss: 4.918
# Epoch: 180, Loss: 4.508
# Epoch: 181, Loss: 4.945
# Epoch: 182, Loss: 4.932
# Epoch: 183, Loss: 4.838
# Epoch: 184, Loss: 4.761
# Epoch: 185, Loss: 4.547
# Epoch: 186, Loss: 5.114
# Epoch: 187, Loss: 4.457
# Epoch: 188, Loss: 5.184
# Epoch: 189, Loss: 4.550
# Epoch: 190, Loss: 4.593
# Epoch: 191, Loss: 5.285
# Epoch: 192, Loss: 5.055
# Epoch: 193, Loss: 4.416
# Epoch: 194, Loss: 4.704
# Epoch: 195, Loss: 4.624
# Epoch: 196, Loss: 4.697
# Epoch: 197, Loss: 3.826
# Epoch: 198, Loss: 4.440
# Epoch: 199, Loss: 4.999
# Epoch: 200, Loss: 4.797
# Epoch: 201, Loss: 4.998
# Epoch: 202, Loss: 4.708
# Epoch: 203, Loss: 5.054
# Epoch: 204, Loss: 4.699
# Epoch: 205, Loss: 4.708
# Epoch: 206, Loss: 4.374
# Epoch: 207, Loss: 4.689
# Epoch: 208, Loss: 4.333
# Epoch: 209, Loss: 4.464
# Epoch: 210, Loss: 4.069
# Epoch: 211, Loss: 3.958
# Epoch: 212, Loss: 3.590
# Epoch: 213, Loss: 4.761
# Epoch: 214, Loss: 4.350
# Epoch: 215, Loss: 4.958
# Epoch: 216, Loss: 4.385
# Epoch: 217, Loss: 5.232
# Epoch: 218, Loss: 3.904
# Epoch: 219, Loss: 4.947
# Epoch: 220, Loss: 5.982
# Epoch: 221, Loss: 5.264
# Epoch: 222, Loss: 5.215
# Epoch: 223, Loss: 4.945
# Epoch: 224, Loss: 4.039
# Epoch: 225, Loss: 4.896
# Epoch: 226, Loss: 3.826
# Epoch: 227, Loss: 4.181
# Epoch: 228, Loss: 4.218
# Epoch: 229, Loss: 4.135
# Epoch: 230, Loss: 4.247
# Epoch: 231, Loss: 4.139
# Epoch: 232, Loss: 4.082
# Epoch: 233, Loss: 5.336
# Epoch: 234, Loss: 4.845
# Epoch: 235, Loss: 4.360
# Epoch: 236, Loss: 4.060
# Epoch: 237, Loss: 4.271
# Epoch: 238, Loss: 4.087
# Epoch: 239, Loss: 4.288
# Epoch: 240, Loss: 4.793
# Epoch: 241, Loss: 4.618
# Epoch: 242, Loss: 4.862
# Epoch: 243, Loss: 4.463
# Epoch: 244, Loss: 4.017
# Epoch: 245, Loss: 4.395
# Epoch: 246, Loss: 4.033
# Epoch: 247, Loss: 4.145
# Epoch: 248, Loss: 4.727
# Epoch: 249, Loss: 4.043
# Epoch: 250, Loss: 3.681
# Epoch: 251, Loss: 4.402
# Epoch: 252, Loss: 4.801
# Epoch: 253, Loss: 4.186
# Epoch: 254, Loss: 4.560
# Epoch: 255, Loss: 4.469
# Epoch: 256, Loss: 4.840
# Epoch: 257, Loss: 4.286
# Epoch: 258, Loss: 4.255
# Epoch: 259, Loss: 4.119
# Epoch: 260, Loss: 3.663
# Epoch: 261, Loss: 4.282
# Epoch: 262, Loss: 4.371
# Epoch: 263, Loss: 4.200
# Epoch: 264, Loss: 4.088
# Epoch: 265, Loss: 4.386
# Epoch: 266, Loss: 4.240
# Epoch: 267, Loss: 3.792
# Epoch: 268, Loss: 4.684
# Epoch: 269, Loss: 3.852
# Epoch: 270, Loss: 4.619
# Epoch: 271, Loss: 4.382
# Epoch: 272, Loss: 4.016
# Epoch: 273, Loss: 4.805
# Epoch: 274, Loss: 3.644
# Epoch: 275, Loss: 4.673
# Epoch: 276, Loss: 4.396
# Epoch: 277, Loss: 4.294
# Epoch: 278, Loss: 4.054
# Epoch: 279, Loss: 3.432
# Epoch: 280, Loss: 4.294
# Epoch: 281, Loss: 3.596
# Epoch: 282, Loss: 4.799
# Epoch: 283, Loss: 4.052
# Epoch: 284, Loss: 5.332
# Epoch: 285, Loss: 3.316
# Epoch: 286, Loss: 4.442
# Epoch: 287, Loss: 4.445
# Epoch: 288, Loss: 4.039
# Epoch: 289, Loss: 3.485
# Epoch: 290, Loss: 4.449
# Epoch: 291, Loss: 4.517
# Epoch: 292, Loss: 4.484
# Epoch: 293, Loss: 4.604
# Epoch: 294, Loss: 4.003
# Epoch: 295, Loss: 3.745
# Epoch: 296, Loss: 3.569
# Epoch: 297, Loss: 3.819
# Epoch: 298, Loss: 4.011
# Epoch: 299, Loss: 3.801
# Epoch: 300, Loss: 4.146
# Epoch: 301, Loss: 3.502
# Epoch: 302, Loss: 4.593
# Epoch: 303, Loss: 4.026
# Epoch: 304, Loss: 3.704
# Epoch: 305, Loss: 4.245
# Epoch: 306, Loss: 4.446
# Epoch: 307, Loss: 3.897
# Epoch: 308, Loss: 4.376
# Epoch: 309, Loss: 4.679
# Epoch: 310, Loss: 4.232
# Epoch: 311, Loss: 4.273
# Epoch: 312, Loss: 4.258
# Epoch: 313, Loss: 4.426
# Epoch: 314, Loss: 4.435
# Epoch: 315, Loss: 3.679
# Epoch: 316, Loss: 3.856
# Epoch: 317, Loss: 3.421
# Epoch: 318, Loss: 3.734
# Epoch: 319, Loss: 4.188
# Epoch: 320, Loss: 4.389
# Epoch: 321, Loss: 4.704
# Epoch: 322, Loss: 4.036
# Epoch: 323, Loss: 4.705
# Epoch: 324, Loss: 4.224
# Epoch: 325, Loss: 4.510
# Epoch: 326, Loss: 3.589
# Epoch: 327, Loss: 3.871
# Epoch: 328, Loss: 4.351
# Epoch: 329, Loss: 3.633
# Epoch: 330, Loss: 3.696
# Epoch: 331, Loss: 3.782
# Epoch: 332, Loss: 3.948
# Epoch: 333, Loss: 3.756
# Epoch: 334, Loss: 4.268
# Epoch: 335, Loss: 4.047
# Epoch: 336, Loss: 4.987
# Epoch: 337, Loss: 4.078
# Epoch: 338, Loss: 3.933
# Epoch: 339, Loss: 3.758
# Epoch: 340, Loss: 3.940
# Epoch: 341, Loss: 4.034
# Epoch: 342, Loss: 4.388
# Epoch: 343, Loss: 4.176
# Epoch: 344, Loss: 3.997
# Epoch: 345, Loss: 4.048
# Epoch: 346, Loss: 3.664
# Epoch: 347, Loss: 3.997
# Epoch: 348, Loss: 4.320
# Epoch: 349, Loss: 4.411
# Epoch: 350, Loss: 3.650
# Epoch: 351, Loss: 3.876
# Epoch: 352, Loss: 4.418
# Epoch: 353, Loss: 3.915
# Epoch: 354, Loss: 4.345
# Epoch: 355, Loss: 4.279
# Epoch: 356, Loss: 4.974
# Epoch: 357, Loss: 4.248
# Epoch: 358, Loss: 4.101
# Epoch: 359, Loss: 3.969
# Epoch: 360, Loss: 4.410
# Epoch: 361, Loss: 3.826
# Epoch: 362, Loss: 3.793
# Epoch: 363, Loss: 4.228
# Epoch: 364, Loss: 4.685
# Epoch: 365, Loss: 3.930
# Epoch: 366, Loss: 4.552
# Epoch: 367, Loss: 3.643
# Epoch: 368, Loss: 3.662
# Epoch: 369, Loss: 3.854
# Epoch: 370, Loss: 3.924
# Epoch: 371, Loss: 4.586
# Epoch: 372, Loss: 3.769
# Epoch: 373, Loss: 4.529
# Epoch: 374, Loss: 4.261
# Epoch: 375, Loss: 3.812
# Epoch: 376, Loss: 3.996
# Epoch: 377, Loss: 4.581
# Epoch: 378, Loss: 4.330
# Epoch: 379, Loss: 3.846
# Epoch: 380, Loss: 4.048
# Epoch: 381, Loss: 3.554
# Epoch: 382, Loss: 4.172
# Epoch: 383, Loss: 3.790
# Epoch: 384, Loss: 3.906
# Epoch: 385, Loss: 4.289
# Epoch: 386, Loss: 3.934
# Epoch: 387, Loss: 4.226
# Epoch: 388, Loss: 3.740
# Epoch: 389, Loss: 4.205
# Epoch: 390, Loss: 3.667
# Epoch: 391, Loss: 3.924
# Epoch: 392, Loss: 4.081
# Epoch: 393, Loss: 3.882
# Epoch: 394, Loss: 4.347
# Epoch: 395, Loss: 4.165
# Epoch: 396, Loss: 4.325
# Epoch: 397, Loss: 3.568
# Epoch: 398, Loss: 3.703
# Epoch: 399, Loss: 3.965
# Epoch: 400, Loss: 3.915
# Epoch: 401, Loss: 4.260
# Epoch: 402, Loss: 3.995
# Epoch: 403, Loss: 4.099
# Epoch: 404, Loss: 3.816
# Epoch: 405, Loss: 4.107
# Epoch: 406, Loss: 3.995
# Epoch: 407, Loss: 3.708
# Epoch: 408, Loss: 3.696
# Epoch: 409, Loss: 3.624
# Epoch: 410, Loss: 4.200
# Epoch: 411, Loss: 3.827
# Epoch: 412, Loss: 4.418
# Epoch: 413, Loss: 3.807
# Epoch: 414, Loss: 4.215
# Epoch: 415, Loss: 3.812
# Epoch: 416, Loss: 3.681
# Epoch: 417, Loss: 4.208
# Epoch: 418, Loss: 3.795
# Epoch: 419, Loss: 4.176
# Epoch: 420, Loss: 3.890
# Epoch: 421, Loss: 3.742
# Epoch: 422, Loss: 3.747
# Epoch: 423, Loss: 3.773
# Epoch: 424, Loss: 3.885
# Epoch: 425, Loss: 4.050
# Epoch: 426, Loss: 3.718
# Epoch: 427, Loss: 4.501
# Epoch: 428, Loss: 4.449
# Epoch: 429, Loss: 4.199
# Epoch: 430, Loss: 3.829
# Epoch: 431, Loss: 4.083
# Epoch: 432, Loss: 3.946
# Epoch: 433, Loss: 4.362
# Epoch: 434, Loss: 3.297
# Epoch: 435, Loss: 4.167
# Epoch: 436, Loss: 3.843
# Epoch: 437, Loss: 3.723
# Epoch: 438, Loss: 4.030
# Epoch: 439, Loss: 4.203
# Epoch: 440, Loss: 3.536
# Epoch: 441, Loss: 3.787
# Epoch: 442, Loss: 3.701
# Epoch: 443, Loss: 4.296
# Epoch: 444, Loss: 4.349
# Epoch: 445, Loss: 4.424
# Epoch: 446, Loss: 3.770
# Epoch: 447, Loss: 4.223
# Epoch: 448, Loss: 4.286
# Epoch: 449, Loss: 3.986
# Epoch: 450, Loss: 4.158
# Epoch: 451, Loss: 3.821
# Epoch: 452, Loss: 3.775
# Epoch: 453, Loss: 3.803
# Epoch: 454, Loss: 3.976
# Epoch: 455, Loss: 3.713
# Epoch: 456, Loss: 3.339
# Epoch: 457, Loss: 4.063
# Epoch: 458, Loss: 4.239
# Epoch: 459, Loss: 4.121
# Epoch: 460, Loss: 4.460
# Epoch: 461, Loss: 3.580
# Epoch: 462, Loss: 3.866
# Epoch: 463, Loss: 4.113
# Epoch: 464, Loss: 3.944
# Epoch: 465, Loss: 4.102
# Epoch: 466, Loss: 3.584
# Epoch: 467, Loss: 3.802
# Epoch: 468, Loss: 3.846
# Epoch: 469, Loss: 3.920
# Epoch: 470, Loss: 3.580
# Epoch: 471, Loss: 3.813
# Epoch: 472, Loss: 4.047
# Epoch: 473, Loss: 3.539
# Epoch: 474, Loss: 3.994
# Epoch: 475, Loss: 3.843
# Epoch: 476, Loss: 3.900
# Epoch: 477, Loss: 3.994
# Epoch: 478, Loss: 3.452
# Epoch: 479, Loss: 3.873
# Epoch: 480, Loss: 3.603
# Epoch: 481, Loss: 3.925
# Epoch: 482, Loss: 3.821
# Epoch: 483, Loss: 3.779
# Epoch: 484, Loss: 4.063
# Epoch: 485, Loss: 3.382
# Epoch: 486, Loss: 3.626
# Epoch: 487, Loss: 3.733
# Epoch: 488, Loss: 3.442
# Epoch: 489, Loss: 3.979
# Epoch: 490, Loss: 3.880
# Epoch: 491, Loss: 4.193
# Epoch: 492, Loss: 4.082
# Epoch: 493, Loss: 3.944
# Epoch: 494, Loss: 3.675
# Epoch: 495, Loss: 4.252
# Epoch: 496, Loss: 3.554
# Epoch: 497, Loss: 3.956
# Epoch: 498, Loss: 3.827
# Epoch: 499, Loss: 3.380
# Epoch: 500, Loss: 4.512
# Epoch: 501, Loss: 3.716
# Epoch: 502, Loss: 3.465
# Epoch: 503, Loss: 4.415
# Epoch: 504, Loss: 3.687
# Epoch: 505, Loss: 4.081
# Epoch: 506, Loss: 3.666
# Epoch: 507, Loss: 4.048
# Epoch: 508, Loss: 3.624
# Epoch: 509, Loss: 3.730
# Epoch: 510, Loss: 3.564
# Epoch: 511, Loss: 3.810
# Epoch: 512, Loss: 3.570
# Epoch: 513, Loss: 4.112
# Epoch: 514, Loss: 3.631
# Epoch: 515, Loss: 3.766
# Epoch: 516, Loss: 4.097
# Epoch: 517, Loss: 4.027
# Epoch: 518, Loss: 3.749
# Epoch: 519, Loss: 4.008
# Epoch: 520, Loss: 3.750
# Epoch: 521, Loss: 3.962
# Epoch: 522, Loss: 3.983
# Epoch: 523, Loss: 3.825
# Epoch: 524, Loss: 3.941
# Epoch: 525, Loss: 4.139
# Epoch: 526, Loss: 3.966
# Epoch: 527, Loss: 4.053
# Epoch: 528, Loss: 3.687
# Epoch: 529, Loss: 3.976
# Epoch: 530, Loss: 3.600
# Epoch: 531, Loss: 3.454
# Epoch: 532, Loss: 3.731
# Epoch: 533, Loss: 4.575
# Epoch: 534, Loss: 4.067
# Epoch: 535, Loss: 4.072
# Epoch: 536, Loss: 3.103
# Epoch: 537, Loss: 4.016
# Epoch: 538, Loss: 4.031
# Epoch: 539, Loss: 3.547
# Epoch: 540, Loss: 3.939
# Epoch: 541, Loss: 3.908
# Epoch: 542, Loss: 3.505
# Epoch: 543, Loss: 4.153
# Epoch: 544, Loss: 3.255
# Epoch: 545, Loss: 3.756
# Epoch: 546, Loss: 3.915
# Epoch: 547, Loss: 3.956
# Epoch: 548, Loss: 4.136
# Epoch: 549, Loss: 3.516
# Epoch: 550, Loss: 3.837
# Epoch: 551, Loss: 3.640
# Epoch: 552, Loss: 2.707
# Epoch: 553, Loss: 3.917
# Epoch: 554, Loss: 3.969
# Epoch: 555, Loss: 3.782
# Epoch: 556, Loss: 4.075
# Epoch: 557, Loss: 3.569
# Epoch: 558, Loss: 3.938
# Epoch: 559, Loss: 3.623
# Epoch: 560, Loss: 3.764
# Epoch: 561, Loss: 4.216
# Epoch: 562, Loss: 3.594
# Epoch: 563, Loss: 3.826
# Epoch: 564, Loss: 3.494
# Epoch: 565, Loss: 3.943
# Epoch: 566, Loss: 3.729
# Epoch: 567, Loss: 3.879
# Epoch: 568, Loss: 3.701
# Epoch: 569, Loss: 3.503
# Epoch: 570, Loss: 4.031
# Epoch: 571, Loss: 3.990
# Epoch: 572, Loss: 4.050
# Epoch: 573, Loss: 3.587
# Epoch: 574, Loss: 4.192
# Epoch: 575, Loss: 3.974
# Epoch: 576, Loss: 3.555
# Epoch: 577, Loss: 4.144
# Epoch: 578, Loss: 3.464
# Epoch: 579, Loss: 3.879
# Epoch: 580, Loss: 3.343
# Epoch: 581, Loss: 4.046
# Epoch: 582, Loss: 4.363
# Epoch: 583, Loss: 3.272
# Epoch: 584, Loss: 3.482
# Epoch: 585, Loss: 3.832
# Epoch: 586, Loss: 3.715
# Epoch: 587, Loss: 3.915
# Epoch: 588, Loss: 4.006
# Epoch: 589, Loss: 3.687
# Epoch: 590, Loss: 3.873
# Epoch: 591, Loss: 3.509
# Epoch: 592, Loss: 4.181
# Epoch: 593, Loss: 3.370
# Epoch: 594, Loss: 4.389
# Epoch: 595, Loss: 4.467
# Epoch: 596, Loss: 3.989
# Epoch: 597, Loss: 3.629
# Epoch: 598, Loss: 3.760
# Epoch: 599, Loss: 3.318
# Epoch: 600, Loss: 3.437
# Epoch: 601, Loss: 3.751
# Epoch: 602, Loss: 4.247
# Epoch: 603, Loss: 3.824
# Epoch: 604, Loss: 3.747
# Epoch: 605, Loss: 3.822
# Epoch: 606, Loss: 3.506
# Epoch: 607, Loss: 3.410
# Epoch: 608, Loss: 3.652
# Epoch: 609, Loss: 3.541
# Epoch: 610, Loss: 3.722
# Epoch: 611, Loss: 3.591
# Epoch: 612, Loss: 3.454
# Epoch: 613, Loss: 3.864
# Epoch: 614, Loss: 4.123
# Epoch: 615, Loss: 4.058
# Epoch: 616, Loss: 3.646
# Epoch: 617, Loss: 3.657
# Epoch: 618, Loss: 4.170
# Epoch: 619, Loss: 4.579
# Epoch: 620, Loss: 3.770
# Epoch: 621, Loss: 3.564
# Epoch: 622, Loss: 3.699
# Epoch: 623, Loss: 3.549
# Epoch: 624, Loss: 4.273
# Epoch: 625, Loss: 3.446
# Epoch: 626, Loss: 3.560
# Epoch: 627, Loss: 4.175
# Epoch: 628, Loss: 3.735
# Epoch: 629, Loss: 3.735
# Epoch: 630, Loss: 3.719
# Epoch: 631, Loss: 3.881
# Epoch: 632, Loss: 3.844
# Epoch: 633, Loss: 3.655
# Epoch: 634, Loss: 3.401
# Epoch: 635, Loss: 3.344
# Epoch: 636, Loss: 3.299
# Epoch: 637, Loss: 4.065
# Epoch: 638, Loss: 3.800
# Epoch: 639, Loss: 3.332
# Epoch: 640, Loss: 3.721
# Epoch: 641, Loss: 3.677
# Epoch: 642, Loss: 3.201
# Epoch: 643, Loss: 3.940
# Epoch: 644, Loss: 4.284
# Epoch: 645, Loss: 3.683
# Epoch: 646, Loss: 3.344
# Epoch: 647, Loss: 3.879
# Epoch: 648, Loss: 3.683
# Epoch: 649, Loss: 3.041
# Epoch: 650, Loss: 4.046
# Epoch: 651, Loss: 3.503
# Epoch: 652, Loss: 3.313
# Epoch: 653, Loss: 3.668
# Epoch: 654, Loss: 3.767
# Epoch: 655, Loss: 3.619
# Epoch: 656, Loss: 3.250
# Epoch: 657, Loss: 3.675
# Epoch: 658, Loss: 3.808
# Epoch: 659, Loss: 3.792
# Epoch: 660, Loss: 3.642
# Epoch: 661, Loss: 3.636
# Epoch: 662, Loss: 3.612
# Epoch: 663, Loss: 3.681
# Epoch: 664, Loss: 3.715
# Epoch: 665, Loss: 4.124
# Epoch: 666, Loss: 3.603
# Epoch: 667, Loss: 3.489
# Epoch: 668, Loss: 3.439
# Epoch: 669, Loss: 3.570
# Epoch: 670, Loss: 3.877
# Epoch: 671, Loss: 3.672
# Epoch: 672, Loss: 3.987
# Epoch: 673, Loss: 3.796
# Epoch: 674, Loss: 3.440
# Epoch: 675, Loss: 4.172
# Epoch: 676, Loss: 3.766
# Epoch: 677, Loss: 3.544
# Epoch: 678, Loss: 3.752
# Epoch: 679, Loss: 3.530
# Epoch: 680, Loss: 3.459
# Epoch: 681, Loss: 3.299
# Epoch: 682, Loss: 3.803
# Epoch: 683, Loss: 3.720
# Epoch: 684, Loss: 3.460
# Epoch: 685, Loss: 3.528
# Epoch: 686, Loss: 3.412
# Epoch: 687, Loss: 3.395
# Epoch: 688, Loss: 3.225
# Epoch: 689, Loss: 3.670
# Epoch: 690, Loss: 3.470
# Epoch: 691, Loss: 3.292
# Epoch: 692, Loss: 3.485
# Epoch: 693, Loss: 3.690
# Epoch: 694, Loss: 3.400
# Epoch: 695, Loss: 3.630
# Epoch: 696, Loss: 3.696
# Epoch: 697, Loss: 4.297
# Epoch: 698, Loss: 3.718
# Epoch: 699, Loss: 3.854
# Epoch: 700, Loss: 3.850
# Epoch: 701, Loss: 3.461
# Epoch: 702, Loss: 3.560
# Epoch: 703, Loss: 3.647
# Epoch: 704, Loss: 3.587
# Epoch: 705, Loss: 3.268
# Epoch: 706, Loss: 3.697
# Epoch: 707, Loss: 3.513
# Epoch: 708, Loss: 3.874
# Epoch: 709, Loss: 3.690
# Epoch: 710, Loss: 3.903
# Epoch: 711, Loss: 3.638
# Epoch: 712, Loss: 3.792
# Epoch: 713, Loss: 3.508
# Epoch: 714, Loss: 3.843
# Epoch: 715, Loss: 3.777
# Epoch: 716, Loss: 3.413
# Epoch: 717, Loss: 4.111
# Epoch: 718, Loss: 3.549
# Epoch: 719, Loss: 3.575
# Epoch: 720, Loss: 3.621
# Epoch: 721, Loss: 3.744
# Epoch: 722, Loss: 3.259
# Epoch: 723, Loss: 3.230
# Epoch: 724, Loss: 3.368
# Epoch: 725, Loss: 3.107
# Epoch: 726, Loss: 3.931
# Epoch: 727, Loss: 4.047
# Epoch: 728, Loss: 3.738
# Epoch: 729, Loss: 4.009
# Epoch: 730, Loss: 3.983
# Epoch: 731, Loss: 3.889
# Epoch: 732, Loss: 3.621
# Epoch: 733, Loss: 3.367
# Epoch: 734, Loss: 3.821
# Epoch: 735, Loss: 3.281
# Epoch: 736, Loss: 3.339
# Epoch: 737, Loss: 3.506
# Epoch: 738, Loss: 3.752
# Epoch: 739, Loss: 3.363
# Epoch: 740, Loss: 3.300
# Epoch: 741, Loss: 3.550
# Epoch: 742, Loss: 3.531
# Epoch: 743, Loss: 3.683
# Epoch: 744, Loss: 3.267
# Epoch: 745, Loss: 3.796
# Epoch: 746, Loss: 3.827
# Epoch: 747, Loss: 3.702
# Epoch: 748, Loss: 3.726
# Epoch: 749, Loss: 3.469
# Epoch: 750, Loss: 3.444
# Epoch: 751, Loss: 3.455
# Epoch: 752, Loss: 3.346
# Epoch: 753, Loss: 3.906
# Epoch: 754, Loss: 3.955
# Epoch: 755, Loss: 3.868
# Epoch: 756, Loss: 3.244
# Epoch: 757, Loss: 3.426
# Epoch: 758, Loss: 3.585
# Epoch: 759, Loss: 3.437
# Epoch: 760, Loss: 3.321
# Epoch: 761, Loss: 3.474
# Epoch: 762, Loss: 3.619
# Epoch: 763, Loss: 3.547
# Epoch: 764, Loss: 3.317
# Epoch: 765, Loss: 3.570
# Epoch: 766, Loss: 3.646
# Epoch: 767, Loss: 3.797
# Epoch: 768, Loss: 3.459
# Epoch: 769, Loss: 3.617
# Epoch: 770, Loss: 3.544
# Epoch: 771, Loss: 3.821
# Epoch: 772, Loss: 3.584
# Epoch: 773, Loss: 3.938
# Epoch: 774, Loss: 3.485
# Epoch: 775, Loss: 3.542
# Epoch: 776, Loss: 3.886
# Epoch: 777, Loss: 3.461
# Epoch: 778, Loss: 3.478
# Epoch: 779, Loss: 3.497
# Epoch: 780, Loss: 3.336
# Epoch: 781, Loss: 3.446
# Epoch: 782, Loss: 3.686
# Epoch: 783, Loss: 3.622
# Epoch: 784, Loss: 3.467
# Epoch: 785, Loss: 2.938
# Epoch: 786, Loss: 3.523
# Epoch: 787, Loss: 3.346
# Epoch: 788, Loss: 3.484
# Epoch: 789, Loss: 3.754
# Epoch: 790, Loss: 3.647
# Epoch: 791, Loss: 3.233
# Epoch: 792, Loss: 3.521
# Epoch: 793, Loss: 3.664
# Epoch: 794, Loss: 3.514
# Epoch: 795, Loss: 3.214
# Epoch: 796, Loss: 3.934
# Epoch: 797, Loss: 3.264
# Epoch: 798, Loss: 3.287
# Epoch: 799, Loss: 3.648
# Epoch: 800, Loss: 3.717
# Epoch: 801, Loss: 3.064
# Epoch: 802, Loss: 3.351
# Epoch: 803, Loss: 3.504
# Epoch: 804, Loss: 3.186
# Epoch: 805, Loss: 3.877
# Epoch: 806, Loss: 3.798
# Epoch: 807, Loss: 2.867
# Epoch: 808, Loss: 3.180
# Epoch: 809, Loss: 3.504
# Epoch: 810, Loss: 3.983
# Epoch: 811, Loss: 3.234
# Epoch: 812, Loss: 3.709
# Epoch: 813, Loss: 3.472
# Epoch: 814, Loss: 3.542
# Epoch: 815, Loss: 3.592
# Epoch: 816, Loss: 3.359
# Epoch: 817, Loss: 2.959
# Epoch: 818, Loss: 3.477
# Epoch: 819, Loss: 3.617
# Epoch: 820, Loss: 3.751
# Epoch: 821, Loss: 3.616
# Epoch: 822, Loss: 3.537
# Epoch: 823, Loss: 3.388
# Epoch: 824, Loss: 3.571
# Epoch: 825, Loss: 3.667
# Epoch: 826, Loss: 3.450
# Epoch: 827, Loss: 3.589
# Epoch: 828, Loss: 3.314
# Epoch: 829, Loss: 3.767
# Epoch: 830, Loss: 3.944
# Epoch: 831, Loss: 3.741
# Epoch: 832, Loss: 3.154
# Epoch: 833, Loss: 3.579
# Epoch: 834, Loss: 3.856
# Epoch: 835, Loss: 3.275
# Epoch: 836, Loss: 3.519
# Epoch: 837, Loss: 3.569
# Epoch: 838, Loss: 3.837
# Epoch: 839, Loss: 3.296
# Epoch: 840, Loss: 3.343
# Epoch: 841, Loss: 3.706
# Epoch: 842, Loss: 3.203
# Epoch: 843, Loss: 3.871
# Epoch: 844, Loss: 3.372
# Epoch: 845, Loss: 3.522
# Epoch: 846, Loss: 3.649
# Epoch: 847, Loss: 3.213
# Epoch: 848, Loss: 3.352
# Epoch: 849, Loss: 4.255
# Epoch: 850, Loss: 3.860
# Epoch: 851, Loss: 3.556
# Epoch: 852, Loss: 3.799
# Epoch: 853, Loss: 3.659
# Epoch: 854, Loss: 3.877
# Epoch: 855, Loss: 3.370
# Epoch: 856, Loss: 3.311
# Epoch: 857, Loss: 3.765
# Epoch: 858, Loss: 3.483
# Epoch: 859, Loss: 3.729
# Epoch: 860, Loss: 3.712
# Epoch: 861, Loss: 3.144
# Epoch: 862, Loss: 4.067
# Epoch: 863, Loss: 3.020
# Epoch: 864, Loss: 3.360
# Epoch: 865, Loss: 3.391
# Epoch: 866, Loss: 3.632
# Epoch: 867, Loss: 3.548
# Epoch: 868, Loss: 3.610
# Epoch: 869, Loss: 3.148
# Epoch: 870, Loss: 3.654
# Epoch: 871, Loss: 3.258
# Epoch: 872, Loss: 3.952
# Epoch: 873, Loss: 3.650
# Epoch: 874, Loss: 3.510
# Epoch: 875, Loss: 3.517
# Epoch: 876, Loss: 3.707
# Epoch: 877, Loss: 3.529
# Epoch: 878, Loss: 3.361
# Epoch: 879, Loss: 3.629
# Epoch: 880, Loss: 3.424
# Epoch: 881, Loss: 3.705
# Epoch: 882, Loss: 3.379
# Epoch: 883, Loss: 3.477
# Epoch: 884, Loss: 3.035
# Epoch: 885, Loss: 3.671
# Epoch: 886, Loss: 3.493
# Epoch: 887, Loss: 3.700
# Epoch: 888, Loss: 3.511
# Epoch: 889, Loss: 3.375
# Epoch: 890, Loss: 3.393
# Epoch: 891, Loss: 3.280
# Epoch: 892, Loss: 3.463
# Epoch: 893, Loss: 3.455
# Epoch: 894, Loss: 3.558
# Epoch: 895, Loss: 2.844
# Epoch: 896, Loss: 3.632
# Epoch: 897, Loss: 3.229
# Epoch: 898, Loss: 3.331
# Epoch: 899, Loss: 3.555
# Epoch: 900, Loss: 3.545
# Epoch: 901, Loss: 3.027
# Epoch: 902, Loss: 3.338
# Epoch: 903, Loss: 3.293
# Epoch: 904, Loss: 3.605
# Epoch: 905, Loss: 3.698
# Epoch: 906, Loss: 3.325
# Epoch: 907, Loss: 3.788
# Epoch: 908, Loss: 3.413
# Epoch: 909, Loss: 3.782
# Epoch: 910, Loss: 2.951
# Epoch: 911, Loss: 3.413
# Epoch: 912, Loss: 3.341
# Epoch: 913, Loss: 3.505
# Epoch: 914, Loss: 3.777
# Epoch: 915, Loss: 3.884
# Epoch: 916, Loss: 3.290
# Epoch: 917, Loss: 3.482
# Epoch: 918, Loss: 3.170
# Epoch: 919, Loss: 3.533
# Epoch: 920, Loss: 3.451
# Epoch: 921, Loss: 3.774
# Epoch: 922, Loss: 3.576
# Epoch: 923, Loss: 3.672
# Epoch: 924, Loss: 3.247
# Epoch: 925, Loss: 3.358
# Epoch: 926, Loss: 3.351
# Epoch: 927, Loss: 3.267
# Epoch: 928, Loss: 3.484
# Epoch: 929, Loss: 3.532
# Epoch: 930, Loss: 3.424
# Epoch: 931, Loss: 3.376
# Epoch: 932, Loss: 3.479
# Epoch: 933, Loss: 3.277
# Epoch: 934, Loss: 3.707
# Epoch: 935, Loss: 3.250
# Epoch: 936, Loss: 3.449
# Epoch: 937, Loss: 3.446
# Epoch: 938, Loss: 3.512
# Epoch: 939, Loss: 3.286
# Epoch: 940, Loss: 3.848
# Epoch: 941, Loss: 3.401
# Epoch: 942, Loss: 3.110
# Epoch: 943, Loss: 3.226
# Epoch: 944, Loss: 3.404
# Epoch: 945, Loss: 3.232
# Epoch: 946, Loss: 3.634
# Epoch: 947, Loss: 3.186
# Epoch: 948, Loss: 3.462
# Epoch: 949, Loss: 3.188
# Epoch: 950, Loss: 3.510
# Epoch: 951, Loss: 3.709
# Epoch: 952, Loss: 3.415
# Epoch: 953, Loss: 3.313
# Epoch: 954, Loss: 3.527
# Epoch: 955, Loss: 3.534
# Epoch: 956, Loss: 3.656
# Epoch: 957, Loss: 3.568
# Epoch: 958, Loss: 3.156
# Epoch: 959, Loss: 3.302
# Epoch: 960, Loss: 3.267
# Epoch: 961, Loss: 3.198
# Epoch: 962, Loss: 3.863
# Epoch: 963, Loss: 3.466
# Epoch: 964, Loss: 3.504
# Epoch: 965, Loss: 3.403
# Epoch: 966, Loss: 3.710
# Epoch: 967, Loss: 3.951
# Epoch: 968, Loss: 3.544
# Epoch: 969, Loss: 3.731
# Epoch: 970, Loss: 3.367
# Epoch: 971, Loss: 3.489
# Epoch: 972, Loss: 3.572
# Epoch: 973, Loss: 3.412
# Epoch: 974, Loss: 3.659
# Epoch: 975, Loss: 3.609
# Epoch: 976, Loss: 3.311
# Epoch: 977, Loss: 3.263
# Epoch: 978, Loss: 3.402
# Epoch: 979, Loss: 3.365
# Epoch: 980, Loss: 3.600
# Epoch: 981, Loss: 3.414
# Epoch: 982, Loss: 3.439
# Epoch: 983, Loss: 3.531
# Epoch: 984, Loss: 3.328
# Epoch: 985, Loss: 3.095
# Epoch: 986, Loss: 3.266
# Epoch: 987, Loss: 3.413
# Epoch: 988, Loss: 4.160
# Epoch: 989, Loss: 3.229
# Epoch: 990, Loss: 3.198
# Epoch: 991, Loss: 3.441
# Epoch: 992, Loss: 3.340
# Epoch: 993, Loss: 3.525
# Epoch: 994, Loss: 3.281
# Epoch: 995, Loss: 3.564
# Epoch: 996, Loss: 3.850
# Epoch: 997, Loss: 3.551
# Epoch: 998, Loss: 3.585
# Epoch: 999, Loss: 3.479
# Epoch: 1000, Loss: 3.440
